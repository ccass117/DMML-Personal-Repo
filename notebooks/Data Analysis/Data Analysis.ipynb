# %% [markdown]
# #Importing Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dataset = pd.read_csv('Tabular Dataset.csv')

# %% [markdown]
# #The Tabular Data

# %%
dataset.head()
# Out:
#    National\r\nDex  Pokemon\r\nName  HP  Attack  Defense  Special\r\nAttack  \
# 0              1.0        Bulbasaur  45      49       49                 65
# 1              2.0          Ivysaur  60      62       63                 80
# 2              3.0         Venusaur  80      82       83                100
# 3              3.1  Venusaur (Mega)  80     100      123                122
# 4              4.0       Charmander  39      52       43                 60
#
#    Special\r\nDefense  Speed  Total  Ability I Ability II Hidden Ability  \
# 0                  65     45    318   Overgrow        NaN    Chlorophyll
# 1                  80     60    405   Overgrow        NaN    Chlorophyll
# 2                 100     80    525   Overgrow        NaN    Chlorophyll
# 3                 120     80    625  Thick Fat        NaN            NaN
# 4                  50     65    309      Blaze        NaN    Solar Power
#
#    Weight (kg)  Height (m) Pokedex Color Egg Group I Egg Group II Type I  \
# 0          6.9         0.7         Green     Monster        Grass  Grass
# 1         13.0         1.0         Green     Monster        Grass  Grass
# 2        100.0         2.0         Green     Monster        Grass  Grass
# 3        155.5         2.4         Green     Monster        Grass  Grass
# 4          8.5         0.6           Red     Monster       Dragon   Fire
#
#   Type II
# 0  Poison
# 1  Poison
# 2  Poison
# 3  Poison
# 4     NaN

# %% [markdown]
# This data has all the Tabular information about every Pokemon that we wished to use for the project.
#
# - The 'National Dex' number is used to ID every Pokemon, as well as their 'Pokemon Name' for convenience.
# - Their 'HP', 'ATK', 'DEF', 'SP.ATK', 'SP.DEF', and 'SPEED' are all stat values of the Pokemon, which can be used to determine whether specific higher or lower stats can provide information on a Pokemon's typing.
# - The 'Total' stats are the combined value of the previous 6 stats to see if higher total stats are more common with certain types.
# - Every Pokemon has an 'Ability I', which ingame is a passive power that the Pokemon has, and in our case we are trying to find whether certain abilities commonly lead to the same types.
# - Some Pokemon also have an 'Ability II' and/or a 'Hidden Ability' which is of the same premise.
# - The official 'Weight' and 'Height' of the Pokemon to see wether they impact the Pokemon types.
# - The 'Pokedex Color' is the official ingame classification of what colour a Pokemon is, irregardless of whether the Pokemon is visually predominantly that colour.
# - 'Egg Group I' and 'Egg Group II' are further classifications, based on which Pokemoon are compatible for breeding.
# - 'Type I' and 'Type II' are the one or two Pokemon types that we are hoping to predict and learn more about.

# %%
type_colour_map = {
    'Grass' : '#71c558',
    'Fire' : '#ea7a3c',
    'Water' : '#539ae2',
    'Bug' : '#94bc4a',
    'Normal' : '#aab09f',
    'Dark' : '#736c75',
    'Poison' : '#b468b7',
    'Electric' : '#e5c531',
    'Ground' : '#cc9f4f',
    'Ice' : '#70cbd4',
    'Fairy' : '#e397d1',
    'Steel' : '#89a1b0',
    'Fighting' : '#cb5f48',
    'Psychic' : '#e5709b',
    'Rock' : '#b2a061',
    'Ghost' : '#846ab6',
    'Dragon' : '#6a7baf',
    'Flying' : '#7da6de'
}

type_order = ['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Dark', 'Poison', 'Electric', 'Ground', 'Ice', 'Fairy', 'Steel', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Dragon', 'Flying']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Pokedex Colour vs Type

# %% [markdown]
# The colour of a Pokemon could be a good example of how we can learn a Pokemon's type I or type II. By learning which colours predominantly make up a type, we should be able to make predictions on future Pokemon's types.

# %%
colour = dataset['Pokedex Color'].values.tolist()
typeI = dataset['Type I'].values.tolist()
typeII = dataset['Type II'].values.tolist()

colour_map = {
    'Black' : '#000000',
    'Blue' : '#0000FF',
    'Brown' : '#B16620',
    'Gray' : '#AAAAAA',
    'Green' : '#00FF00',
    'Pink' : '#FF9AED',
    'Purple' : '#FF00FF',
    'Red' : '#FF0000',
    'White' : '#FFFFFF',
    'Yellow' : '#FFFF00'
}


dataframe = {
    'Pokedex Colour': colour,
    'Type I' : typeI,
    'Type II' : typeII
}

pd_df = pd.DataFrame(dataframe)

pd_df_count_typeI = pd_df.groupby(['Type I', 'Pokedex Colour']).size()
pd_df_count_typeI = pd_df_count_typeI.to_frame(name='Count').reset_index()

pd_df_count_typeII = pd_df.groupby(['Type II', 'Pokedex Colour']).size()
pd_df_count_typeII = pd_df_count_typeII.to_frame(name='Count').reset_index()


fig_typeI = px.bar(
    pd_df_count_typeI,
    x='Type I',
    y='Count',
    color='Pokedex Colour',
    title='Pokedex Colour vs Type I',
    color_discrete_map=colour_map,
    category_orders={'Type I': type_order}
)

fig_typeII = px.bar(
    pd_df_count_typeII,
    x='Type II',
    y='Count',
    color='Pokedex Colour',
    title='Pokedex Colour vs Type II',
    color_discrete_map=colour_map,
    category_orders={'Type II': type_order}
)




fig_typeI.show()
fig_typeII.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="beccd44d-4b8e-41f2-87e2-6b4990d3e735" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beccd44d-4b8e-41f2-87e2-6b4990d3e735")) {                    Plotly.newPlot(                        "beccd44d-4b8e-41f2-87e2-6b4990d3e735",                        [{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Black\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Black","marker":{"color":"#000000","pattern":{"shape":""}},"name":"Black","offsetgroup":"Black","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fire","Ghost","Grass","Ground","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[2,16,3,4,1,12,1,3,6,6,5,3,2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Blue\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Blue","marker":{"color":"#0000FF","pattern":{"shape":""}},"name":"Blue","offsetgroup":"Blue","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[8,8,12,9,4,7,2,3,1,6,1,14,11,8,11,13,6,85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Brown\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brown","marker":{"color":"#B16620","pattern":{"shape":""}},"name":"Brown","offsetgroup":"Brown","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[9,7,1,1,2,12,15,13,12,18,3,47,3,5,19,6,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Gray\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gray","marker":{"color":"#AAAAAA","pattern":{"shape":""}},"name":"Gray","offsetgroup":"Gray","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fighting","Fire","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[12,6,9,5,12,1,2,3,8,3,17,3,1,16,17,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Green\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Green","marker":{"color":"#00FF00","pattern":{"shape":""}},"name":"Green","offsetgroup":"Green","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dragon","Electric","Fairy","Fighting","Flying","Ghost","Grass","Ground","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[13,11,3,2,1,2,1,67,7,3,5,7,6,4,14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Pink\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pink","marker":{"color":"#FF9AED","pattern":{"shape":""}},"name":"Pink","offsetgroup":"Pink","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Flying","Grass","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[1,2,1,1,14,1,6,1,16,2,12,2,1,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Purple\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Purple","marker":{"color":"#FF00FF","pattern": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7035bde-c9af-4828-a665-3633d2e415c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7035bde-c9af-4828-a665-3633d2e415c7")) {                    Plotly.newPlot(                        "b7035bde-c9af-4828-a665-3633d2e415c7",                        [{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Gray\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gray","marker":{"color":"#AAAAAA","pattern":{"shape":""}},"name":"Gray","offsetgroup":"Gray","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Electric","Fairy","Fighting","Flying","Ghost","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[2,3,4,5,3,5,5,7,6,3,5,3,7,14,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Green\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Green","marker":{"color":"#00FF00","pattern":{"shape":""}},"name":"Green","offsetgroup":"Green","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Normal","Poison","Psychic","Rock","Steel"],"xaxis":"x","y":[2,7,10,2,2,4,1,14,9,10,3,4,12,4,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Purple\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Purple","marker":{"color":"#FF00FF","pattern":{"shape":""}},"name":"Purple","offsetgroup":"Purple","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Fairy","Fighting","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Steel"],"xaxis":"x","y":[1,6,8,4,2,14,6,1,2,1,2,9,4,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Red\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red","marker":{"color":"#FF0000","pattern":{"shape":""}},"name":"Red","offsetgroup":"Red","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[2,4,3,2,8,4,18,2,6,2,1,4,8,3,6,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=White\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"White","marker":{"color":"#FFFFFF","pattern":{"shape":""}},"name":"White","offsetgroup":"White","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Fairy","Fighting","Fire","Flying","Ghost","Ice","Normal","Poison","Psychic","Steel"],"xaxis":"x","y":[2,2,5,6,5,5,11,4,7,2,3,3,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Blue\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Blue","marker":{"color":"#0000FF","pattern":{"shape":""}},"name":"Blue","offsetgroup":"Blue","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dragon","Electric","Fairy","Fighting","Flying","Ghost","Ground","Ice","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[6,6,3,6,7,21,2,15,5,7,10,3,5,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pokedex Colour=Brown\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brown","marker":{"color":"#B16620","pattern":{"shape":""}},"name":"Brown","offsetgroup":"Brown","orientation":"v","sh ...

# %% [markdown]
# There are a few interesting things we can pull from this data, notably that most Type I seem to have a predominant colour. for example, 'Grass' is frequently green, 'Normal' is brown, 'Electric is yellow, and 'Poison' is purple. There are also some connections that may make less sense, such as bugs being surprisingly predominantly red despite the ingame colour icon being green, and the higher than expected number of blue rock types.
#
# Type II Colours seem to be all over the place in comparison. a high number of green dark types, blue ground types, and psychic seeming ot have a wide mix of colours. These will be harder to make accurate predictions with, but can still be used to a lesser extent.
#
# There is some imbalance in the dataset. for example, flying is the lowest Type I with only 10 Pokemon, while in Type II, flying has 136 Pokemon, over double the next highest which is psychic at 52. Thankfully flying is the only major outlier.

# %% [markdown]
# #Number of Egg Groups vs Number of Types

# %% [markdown]
# Pokemon Egg Groups can tell you which Pokemon they can breed with ingame. with this in mind, it is safe to assume that similar Pokemon with Similar egg groups likely have similar types, however, some Pokemon can have 2 egg groups, while some have 1, much like how some Pokemon have 2 types while some have 1. Here we decided to work out whether Pokemon with a second egg group, were more likely to have a second typing.

# %%
# Step 1: Create the num_types and num_egg_groups columns
num_types = dataset['Type II'].apply(lambda x: 1 if pd.isna(x) else 2)
num_egg_groups = dataset['Egg Group II'].apply(lambda x: 1 if pd.isna(x) else 2)

df = {
    'Type Count' : num_types,
    'Egg Group Count' : num_egg_groups
}

df = pd.DataFrame(df)
# Step 2: Count combinations of num_types and num_egg_groups
type_egg_group_counts = df.groupby(['Type Count', 'Egg Group Count']).size()
type_egg_group_counts = type_egg_group_counts.to_frame(name='Count').reset_index()

# Step 3: Plot with Plotly Express
fig = px.bar(
    type_egg_group_counts,
    x='Type Count',
    y='Count',
    color='Egg Group Count',
    title='Number of Egg Groups vs Number of Types'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f725142b-d62a-4c2e-bd70-74d74c99460a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f725142b-d62a-4c2e-bd70-74d74c99460a")) {                    Plotly.newPlot(                        "f725142b-d62a-4c2e-bd70-74d74c99460a",                        [{"alignmentgroup":"True","hovertemplate":"Type Count=%{x}\u003cbr\u003eCount=%{y}\u003cbr\u003eEgg Group Count=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1,2,1,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,1,2,2],"xaxis":"x","y":[405,146,511,174],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo", ...

# %% [markdown]
# Unfortunately, this exploratory analysis does not give us much information. There are significantly less pokemon with 2 egg groups but that does not seem to impact how likely a pokemon is to having a second typing.
#
# for single type pokemon, 26.49% of the pokemon have a secondary egg group, and for dual type pokemon, 25.4% of the pokemon have a secondary egg group. this difference is pretty much indistinguishable

# %% [markdown]
# #Total vs Type

# %% [markdown]
# By determining the Total stat median, min and max, we should be able to find trends matching with the typing, with some types being significantly weaker, and some being stronger.

# %%
stat_total = dataset['Total']
typeI = dataset['Type I']
typeII = dataset['Type I']

df = {
    'Stat Total' : stat_total,
    'Type I' : typeI,
    'Type II' : typeII
}

df = pd.DataFrame(df)

fig_typeI = px.violin(df, x='Type I', y='Stat Total', color='Type I', color_discrete_map=type_colour_map, category_orders={'Type I':type_order})
fig_typeI.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="39a4f956-7722-4c8c-9e67-c60e5ca4b30d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39a4f956-7722-4c8c-9e67-c60e5ca4b30d")) {                    Plotly.newPlot(                        "39a4f956-7722-4c8c-9e67-c60e5ca4b30d",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eStat Total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grass","marker":{"color":"#71c558"},"name":"Grass","offsetgroup":"Grass","orientation":"v","scalegroup":"True","showlegend":true,"x":["Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass"],"x0":" ","xaxis":"x","y":[318,405,525,625,320,395,490,300,390,490,325,530,530,435,318,414,525,490,250,340,460,180,425,310,405,530,630,220,340,480,295,460,400,335,475,460,318,405,525,280,515,275,450,450,454,334,494,594,535,525,600,600,308,413,528,316,498,280,480,280,480,480,461,294,464,305,489,580,313,405,530,350,531,320,420,530,530,250,480,285,405,210,290,510,570,570,310,420,530,250,460,260,485,485,310,410,530,260,354,510,275,480,304,486,570,590,485,308,508,550,550,550,550,540],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eStat Total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fire","marker":{"color":"#ea7a3c"},"name":"Fire","offsetgroup":"Fire","orientation":"v","scalegroup":"True","showlegend":true,"x":["Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire"],"x0":" ","xaxis":"x","y":[309,405,534,634,634,299,505,350,350,555,555,410,500,425,495,525,580,309,405,534,534,250,430,365,580,680,310,405,530,630,305,460,560,470,420,309,405,534,540,600,308,418,528,316,498,315,480,540,484,307,409,534,382,499,369,507,600,320,420,530,476,485,570,310,420,530,305,525,310,411,530,255,525,525,570,590],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eStat Total=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Water","marker":{"color":"#539ae2"},"name":"Water","offsetgroup":"Water","orientation":"v","scalegroup":"True","showlegend":true,"x":["Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Wat ...

# %% [markdown]
# This data doesnt give us too much information, however, we can tell that dragon has the highest stat total at 780, while water has the lowest at 175. Dragons also have the highest median of 580, so pokemon with high stat totals are more likely to be dragon types.
# It is interesting to see that almost every type fits into one of two catagories, either elongated rhombus shapes, spiking at the top and bottom, with a single gradual grow to the mean, and a single decrease after, or they are shaped with two bulbs, where the type seems to average out before growing again afterwards.
# The only exception to this rule is fighting, which seems to be in a rhombus shape, yet as it approaches the median, it seems to bulb out, suggesting a lot of fighting types have stats around that area.

# %% [markdown]
# #Total vs Number of Types

# %% [markdown]
# Some pokemon have higher stat totals than others, we are hoping that there will be a distinct difference in higher stat pokemon having multiple types so that we are able to more accurately predict if a pokemon has one or two types.

# %%
# Step 1: Create the num_types and num_egg_groups columns
num_types = dataset['Type II'].apply(lambda x: 1 if pd.isna(x) else 2)
stat_total = dataset['Total'].apply(lambda x: '175-296' if x>174 and x<297
                                              else '297-417' if x>296 and x<418
                                              else '418-538' if x>417 and x<539
                                              else '539-659' if x>538 and x<660
                                              else '660-780' if x>659 and x<781
                                              else '780+')

df = {
    'Type Count' : num_types,
    'Stat Total' : stat_total
}

df = pd.DataFrame(df)
# Step 2: Count combinations of num_types and num_egg_groups
type_egg_group_counts = df.groupby(['Type Count', 'Stat Total']).size()
type_egg_group_counts = type_egg_group_counts.to_frame(name='Count').reset_index()

# Step 3: Plot with Plotly Express
fig = px.bar(
    type_egg_group_counts,
    x='Type Count',
    y='Count',
    color='Stat Total',
    title='Stat Total vs Number of Types'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="72d406d0-e468-471a-b47a-0af281951957" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72d406d0-e468-471a-b47a-0af281951957")) {                    Plotly.newPlot(                        "72d406d0-e468-471a-b47a-0af281951957",                        [{"alignmentgroup":"True","hovertemplate":"Stat Total=175-296\u003cbr\u003eType Count=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"175-296","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"175-296","offsetgroup":"175-296","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2],"xaxis":"x","y":[96,57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stat Total=297-417\u003cbr\u003eType Count=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"297-417","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"297-417","offsetgroup":"297-417","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2],"xaxis":"x","y":[178,157],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stat Total=418-538\u003cbr\u003eType Count=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"418-538","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"418-538","offsetgroup":"418-538","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2],"xaxis":"x","y":[215,302],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stat Total=539-659\u003cbr\u003eType Count=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"539-659","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"539-659","offsetgroup":"539-659","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2],"xaxis":"x","y":[50,130],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stat Total=660-780\u003cbr\u003eType Count=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"660-780","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"660-780","offsetgroup":"660-780","orientation":"v","showlegend":true,"textposition":"auto","x":[1,2],"xaxis":"x","y":[12,39],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %% [markdown]
# As with the number of egg groups, the total stats does not give much of an indicator over the number of types apart from extreme values. It appears that pokemon in the lower fifth values (175-296) are more that twice as likely to be monotype, while pokemon in the higher fifth (660-780) are slightly more likely to be dual-type.
#
# 17% of all monotypes are in the lower fifth while 8% of dual types are in the lower fifth
#
# 2% of monotypes are in the upper fifth while 5% of dual types are in the upper fifth

# %% [markdown]
# #Highest Stat vs Type

# %% [markdown]
# Analysing which stat is the highest can hopefully show some trends with certain types being more likely to have a stat higher than the others.

# %%
stats = dataset.iloc[:, 2:8]
typeI = dataset['Type I']
typeII = dataset['Type II']

max_stats = pd.DataFrame(
    {
        'Highest Stat' : stats.idxmax(axis=1),
        'Type I' : typeI,
        'Type II' : typeII
    }
)

stat_typeI_count = max_stats.groupby(['Highest Stat', 'Type I']).size()
stat_typeI_count = stat_typeI_count.to_frame(name='Count').reset_index()
fig_typeI = px.bar(
    stat_typeI_count,
    x='Type I',
    y='Count',
    color='Highest Stat',
    title='Highest Stat vs Type I',
    category_orders={'Type I': type_order}
)


stat_typeII_count = max_stats.groupby(['Highest Stat', 'Type II']).size()
stat_typeII_count = stat_typeII_count.to_frame(name='Count').reset_index()
fig_typeII = px.bar(
    stat_typeII_count,
    x='Type II',
    y='Count',
    color='Highest Stat',
    title='Highest Stat vs Type II',
    category_orders={'Type II': type_order}
)

fig_typeI.show()
fig_typeII.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c0eabdb8-95c5-4b56-961e-dccaa3cf30cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0eabdb8-95c5-4b56-961e-dccaa3cf30cc")) {                    Plotly.newPlot(                        "c0eabdb8-95c5-4b56-961e-dccaa3cf30cc",                        [{"alignmentgroup":"True","hovertemplate":"Highest Stat=Attack\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Attack","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Attack","offsetgroup":"Attack","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[27,21,24,11,5,36,19,2,8,36,21,8,40,14,11,24,11,33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Defense\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Defense","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Defense","offsetgroup":"Defense","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[30,4,5,5,5,1,5,1,17,17,14,6,5,8,3,31,24,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=HP\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"HP","offsetgroup":"HP","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[3,3,2,3,5,5,4,4,13,3,10,39,11,13,2,1,28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Special\r\nAttack\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Special\r\nAttack","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Special\r\nAttack","offsetgroup":"Special\r\nAttack","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[17,11,7,24,3,1,29,1,16,24,9,10,4,34,3,8,24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Special\r\nDefense\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Special\r\nDefense","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Special\r\nDefense","offsetgroup":"Special\r\nDefense","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[9,6,6,17,2,3,1,1,7,4,4,4,2,11,4,2,19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Speed\u003cbr\u003eType I=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Speed","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Speed","offsetgroup":"Speed","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Water"],"xaxis":"x","y":[13,11,5,30,1,5,16,5,1,17,4,6,38,9,10,10,28],"yaxis":"y","type":"bar ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="69e728d9-417a-4449-bc2a-dbcb805da9ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69e728d9-417a-4449-bc2a-dbcb805da9ed")) {                    Plotly.newPlot(                        "69e728d9-417a-4449-bc2a-dbcb805da9ed",                        [{"alignmentgroup":"True","hovertemplate":"Highest Stat=Attack\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Attack","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Attack","offsetgroup":"Attack","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[4,20,12,2,5,30,6,32,11,8,13,11,1,13,10,7,13,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Defense\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Defense","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Defense","offsetgroup":"Defense","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"xaxis":"x","y":[1,2,6,4,6,5,3,8,8,11,11,3,1,4,8,13,13,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=HP\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"HP","offsetgroup":"HP","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dragon","Electric","Fairy","Fire","Flying","Ghost","Grass","Ground","Ice","Poison","Psychic","Steel","Water"],"xaxis":"x","y":[4,4,4,6,1,9,3,2,14,3,3,4,2,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Special\r\nAttack\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Special\r\nAttack","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Special\r\nAttack","offsetgroup":"Special\r\nAttack","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Ground","Ice","Normal","Poison","Psychic","Steel","Water"],"xaxis":"x","y":[2,2,16,1,12,1,9,35,12,4,1,7,19,16,6,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Special\r\nDefense\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Special\r\nDefense","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Special\r\nDefense","offsetgroup":"Special\r\nDefense","orientation":"v","showlegend":true,"textposition":"auto","x":["Bug","Dragon","Fairy","Fighting","Flying","Ghost","Grass","Ice","Normal","Poison","Psychic","Steel","Water"],"xaxis":"x","y":[2,3,7,1,12,2,9,1,2,5,8,4,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Highest Stat=Speed\u003cbr\u003eType II=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Speed","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Speed","offsetgroup":"Speed","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Steel","Water"],"xaxis":"x","y":[5,2,2,8,4,2,40,4,6,2,3,7,3,6,2,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","c ...

# %% [markdown]
# At first, this information does not seem to provide much information, most types seem to have two or even three types that are almost tied for the highest stat, (the notable exception being fighting type, where attack is significantly higher).
#
# Looking deeper though, the most information seems to come from which stats are *least* commonly the highest stat. The prime example of this is Electric type, where not a single pokemon has Special Defence as its highest stat. Bug and Rock types are very unlikely to have high HP, and ground types typically do not have high Special Attack.
#
# Other interesting notes are surprisingly average amount of high attack psychic types (usually known for having high special attack instead)

# %% [markdown]
# #Size vs Type

# %% [markdown]
# By clustering the Height and Weight of every pokemon in a type, we hope to find patterns, perhaps rock or steel types will weighh the most, while fairies will on average weigh the least, and electric types might be smaller as they are typically faster and more agile.

# %%
size_df = {
    'Weight(kg)' : dataset['Weight (kg)'],
    'Height(m)' : dataset['Height (m)'],
    'Type I' : dataset['Type I'],
}

size_df = pd.DataFrame(size_df)

fig = px.scatter(size_df, x='Height(m)', y='Weight(kg)', facet_col='Type I', color='Type I',
                 title='Height vs. Weight by Type I (Faceted)',
                 color_discrete_map=type_colour_map,
                 category_orders={'Type I':type_order})

# LAYOUT COMMANDS #############################################################
fig.for_each_annotation(lambda a: a.update(text=a.text.split('=')[-1]))
fig.for_each_xaxis(lambda xaxis: xaxis.update(title_text=''))
fig.update_layout(
    xaxis_title='Height(m)',
    title_x=0.5
)
###############################################################################

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="70bccfb3-f36b-4723-8493-abcaadce701d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70bccfb3-f36b-4723-8493-abcaadce701d")) {                    Plotly.newPlot(                        "70bccfb3-f36b-4723-8493-abcaadce701d",                        [{"hovertemplate":"Type I=Grass\u003cbr\u003eHeight(m)=%{x}\u003cbr\u003eWeight(kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grass","marker":{"color":"#71c558","symbol":"circle"},"mode":"markers","name":"Grass","showlegend":true,"x":[0.7,1.0,2.0,2.4,0.5,0.8,1.2,0.7,1.0,1.7,0.4,2.0,10.9,1.0,0.9,1.2,1.8,0.4,0.4,0.6,0.8,0.3,0.8,0.5,0.9,1.7,1.9,0.5,1.0,1.3,0.4,1.2,0.3,0.4,1.3,2.0,0.4,1.1,2.2,0.2,0.9,0.4,0.5,0.5,1.4,1.0,2.2,2.7,2.0,1.0,0.2,0.4,0.6,0.8,3.3,0.6,1.1,0.3,0.7,0.5,1.1,1.2,1.0,0.2,0.6,0.6,1.0,2.0,0.4,0.7,1.6,0.9,1.7,0.3,0.7,1.6,1.6,0.3,0.9,0.2,1.0,0.3,0.7,1.2,1.9,0.3,0.3,0.7,2.1,0.4,0.5,0.2,0.3,0.4,0.4,0.9,1.5,0.3,0.6,1.4,0.6,1.2,0.3,0.9,1.2,1.5,0.4,0.1,0.2,1.2,1.2,1.2,1.2,1.8],"xaxis":"x","y":[6.9,13.0,100.0,155.5,5.4,8.6,18.6,4.0,6.4,15.5,2.5,120.0,415.6,35.0,6.4,15.8,100.5,5.8,0.5,1.0,3.0,1.8,8.5,5.0,21.6,52.2,55.2,4.0,28.0,59.6,4.5,39.2,2.0,51.3,77.4,100.0,10.2,97.0,310.0,1.2,14.5,3.3,9.3,9.3,27.0,50.5,135.5,185.0,128.6,25.5,2.1,5.2,8.1,16.0,63.0,10.5,30.5,0.6,6.6,6.6,16.3,19.2,28.0,1.0,10.5,18.8,110.0,200.0,9.0,29.0,90.0,31.0,91.0,1.5,16.0,36.6,37.0,1.5,18.5,1.5,11.5,3.2,8.2,21.4,45.5,0.1,5.0,14.0,90.0,2.2,2.5,0.5,1.0,13.0,4.1,12.2,31.2,6.5,11.9,48.2,0.6,6.0,3.0,15.0,21.0,125.0,4.4,1.1,2.2,39.8,39.8,39.8,39.8,93.0],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Type I=Fire\u003cbr\u003eHeight(m)=%{x}\u003cbr\u003eWeight(kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fire","marker":{"color":"#ea7a3c","symbol":"circle"},"mode":"markers","name":"Fire","showlegend":true,"x":[0.6,1.1,1.7,1.7,1.7,0.6,1.1,0.7,0.8,1.9,2.0,1.0,1.7,1.0,1.3,0.9,2.0,0.5,0.9,1.7,1.6,0.7,0.8,0.7,2.1,3.8,0.4,0.9,1.9,1.9,0.7,1.9,2.5,0.5,0.3,0.5,0.9,1.2,1.6,1.7,0.5,1.0,1.6,0.6,1.0,0.6,1.3,1.3,1.4,0.4,1.0,1.5,0.7,1.2,0.6,1.5,1.7,0.4,0.7,1.8,0.6,2.0,1.8,0.3,0.6,1.4,0.7,3.0,0.4,1.0,1.6,0.6,1.5,1.6,1.2,3.5],"xaxis":"x2","y":[8.5,19.0,90.5,110.5,100.5,9.9,19.9,19.0,22.7,155.0,168.0,30.0,95.0,34.0,44.5,25.0,60.0,7.9,19.0,79.5,69.8,35.0,55.0,21.4,198.0,199.0,2.5,19.5,52.0,52.0,24.0,220.0,320.5,80.4,0.8,6.2,22.0,55.0,68.0,430.0,9.9,55.5,150.0,11.0,28.0,37.5,92.9,92.9,58.0,9.4,14.5,39.0,16.0,24.5,13.5,81.5,195.0,4.3,25.0,83.0,3.4,212.0,13.0,4.5,9.0,33.0,1.0,120.0,9.8,30.7,326.5,10.5,85.0,62.0,36.0,590.0],"yaxis":"y2","type":"scattergl"},{"hovertemplate":"Type I=Water\u003cbr\u003eHeight(m)=%{x}\u003cbr\u003eWeight(kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Water","marker":{"color":"#539ae2","symbol":"circle"},"mode":"markers","name":"Water","showlegend":true,"x":[0.5,1.0,1.6,1.6,0.8,1.7,0.6,1.0,1.3,0.9,1.6,1.2,1.6,2.0,1.1,1.7,0.3,1.5,0.4,1.3,0.4,1.2,0.6,1.3,0.8,1.1,0.9,6.5,6.5,2.5,1.0,0.6,1.1,2.3,0.5,1.2,0.4,0.8,1.1,0.4,1.4,2.0,0.5,0.6,0.6,0.9,2.1,1.8,2.0,0.4,0.7,1.5,1.9,0.5,1.2,1.5,0.6,1.2,0.8,1.8,2.5,2.0,14.5,0.4,0.9,0.6,1.1,0.6,6.2,0.3,0.4,1.7,1.8,1.0,0.6,4.5,9.8,0.4,0.8,1.7,0.7,1.1,0.3,0.3,0.9,0.9,0.4,1.2,1.0,4.2,6.3,0.4,0.3,0.5,0.8,1.5,1.5,0.6,1.0,0.5,0.8,1.5,1.0,1.0,1.0,0.7,1.2,0.5,1.3,1.2,2.2,1.2,1.4,0.3,0.6,1.5,0.0,0.5,1.3,0.4,0.6,1.8,0.2,8.2,0.3,1.8,0.3,0.9,1.3,0.3,0.7,1.9,0.3,1.0,0.5,1.3,2.3,2.0,3.0,3.0,0.5,1.2,1.8,1.2,1.2,1.3,1.3,1.8,2.5,12.0,3.5],"xaxis":"x3","y":[9.0,22.5,85.5,101.1,19.6,76.6,12.4,20.0,54.0,45.5,55.0,36.0,78.5,120.0,90.0,120.0,4.0,132.5,6.5,60.0,8.0,25.0,15.0,39.0,34.5,80.0,10.0,235.0,305.0,220.0,29.0,9.5,25.0,88.8,12.0,22.5,8.5,28.5,33.9,8.5,75.0,79.5,3.9,5.0,12.0,28.5,220.0,152.0,187.0,7.6,28.0,81.9,102.0,2.6,32.5 ...

# %% [markdown]
# We can see that most types seem to have a few outliers, especially when it comes to weight, with most types clustering small, and the occasional instance hundreds of kg above the rest, the biggest case of this is poison, where the outlier is 'Eternamax Eternatus', a giant boss Pokemon in the games, and thus is much larger than every other pokemon, as well as having a high weight to pair with it.
#
# Some other pokemon match, or even beat Eternamax Eternatus, in weight, but it is the largest in height by a lot, and it sticks out from the other relatively small and light poison types.
#
# This information doesnt give us much to work with as a lot of pokemon are clusteres closer to the 0,0 mark, but we can still see that steel have a few more pokemon of higher weight that other types, and flying has the no outliers but this is likely due to having very few Type I flying types

# %% [markdown]
# #HP vs Type

# %% [markdown]
# Comparing different HP stats with types will hopefully provide information... (ill add something here when I can be buggered (aka not right now))

# %%
hp_df = pd.DataFrame(
    {
        'HP' : dataset['HP'],
        'Type I' : dataset['Type I'],
        'Type II' : dataset['Type II']
    }
)

fig_typeI = px.violin(hp_df, x='Type I', y='HP', color='Type I', color_discrete_map=type_colour_map, category_orders={'Type I' : type_order})
fig_typeI.show()

fig_typeII = px.violin(hp_df, x='Type II', y='HP', color='Type II', color_discrete_map=type_colour_map, category_orders={'Type II' : type_order})
fig_typeII.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ff88acf-90e7-464a-b4de-6c2a59e783ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ff88acf-90e7-464a-b4de-6c2a59e783ce")) {                    Plotly.newPlot(                        "4ff88acf-90e7-464a-b4de-6c2a59e783ce",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grass","marker":{"color":"#71c558"},"name":"Grass","offsetgroup":"Grass","orientation":"v","scalegroup":"True","showlegend":true,"x":["Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass"],"x0":" ","xaxis":"x","y":[45,60,80,80,45,60,75,50,65,80,60,95,95,65,45,60,80,75,35,55,75,30,75,40,50,70,70,40,70,90,60,60,50,50,70,99,55,75,95,40,60,45,70,70,74,60,90,90,100,65,100,100,45,60,75,50,75,40,60,45,70,70,75,69,114,44,74,91,56,61,88,66,123,68,78,78,88,40,70,40,60,42,52,72,70,59,50,70,100,40,60,40,70,110,40,61,76,41,52,78,40,55,50,65,111,90,80,40,71,80,80,80,80,106],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fire","marker":{"color":"#ea7a3c"},"name":"Fire","offsetgroup":"Fire","orientation":"v","scalegroup":"True","showlegend":true,"x":["Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire"],"x0":" ","xaxis":"x","y":[39,58,78,78,78,38,73,55,60,90,95,50,65,60,65,65,90,39,58,78,73,40,60,45,115,106,45,60,80,80,60,70,70,70,70,44,64,76,75,91,65,90,110,50,75,70,105,105,85,40,59,75,62,78,62,86,80,45,65,95,75,60,53,50,65,80,50,100,67,81,104,40,85,75,80,105],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type I=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Water","marker":{"color":"#539ae2"},"name":"Water","offsetgroup":"Water","orientation":"v","scalegroup":"True","showlegend":true,"x":["Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="506cedf7-1311-40f3-bc99-31314d825478" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("506cedf7-1311-40f3-bc99-31314d825478")) {                    Plotly.newPlot(                        "506cedf7-1311-40f3-bc99-31314d825478",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Grass","marker":{"color":"#71c558"},"name":"Grass","offsetgroup":"Grass","orientation":"v","scalegroup":"True","showlegend":true,"x":["Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass","Grass"],"x0":" ","xaxis":"x","y":[35,60,40,60,100,40,60,80,66,86,60,50,45,55,75,60,60,60,60,80,43,85,44,49,54,59,55,65,75,85,70,105,100,40,80,85],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fire","marker":{"color":"#ea7a3c"},"name":"Fire","offsetgroup":"Fire","orientation":"v","scalegroup":"True","showlegend":true,"x":["Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire","Fire"],"x0":" ","xaxis":"x","y":[75,45,75,75,100,50,100,105,50,60,60,55,85,100,48,68,80,110,65,55,80],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Water","marker":{"color":"#539ae2"},"name":"Water","offsetgroup":"Water","orientation":"v","scalegroup":"True","showlegend":true,"x":["Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water","Water"],"x0":" ","xaxis":"x","y":[75,35,70,30,60,40,70,90,110,79,50,42,72,50,80,50,50,25,75,70,100,68,68,68,56,80],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bug","marker":{"color":"#94bc4a"},"name":"Bug","offsetgroup":"Bug","orientation":"v","scalegroup":"True","showlegend":true,"x":["Bug","Bug","Bug","Bug","Bug","Bug","Bug","Bug","Bug"],"x0":" ","xaxis":"x","y":[45,75,40,38,68,50,100,30,70],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#aab09f"},"name":"Normal","offsetgroup":"Normal","orientation":"v","scalegroup":"True","showlegend":true,"x":["Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal","Normal"],"x0":" ","xaxis":"x","y":[30,75,38,78,62,86,44,62,93,60,70,130,41,52,78,40,63,70],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Type II=%{x}\u003cbr\u003eHP=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dark","marker":{"color":"#736c75"},"name":"Dark","offsetgroup":"Dark","orientation":"v","scalegroup":"True","showlegend":true,"x":["Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark","Dark" ...

# %% [markdown]
# We unfortunately dont get much information out of this, apart from the occasional outlier, the majority of types have similar average HP stats. The only amusing result is type I bug and type II Ghost having minimum HP stats of 1 thanks to 'Shedinja' being the only pokemon with 1 hp.
